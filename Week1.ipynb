# %% [markdown]
# <a href="https://colab.research.google.com/github/FebryanRizki24/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nama : Febryan Rizki Hidayatullah
#
# ---
#
#
# # Kelas : TI 3F
#
# ---
#
#
# # Nim : 2141720059

# %% [markdown]
# # PRAKTIKUM

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
"https://placekitten.com/800/571"]

#baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame =cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ## PERTANYAAN

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# jawab ->
# **karena di gogle colab sudah menyediakan bermacam2 library yang dapat diakses untuk tugas ini**
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# jawab ->
# **numpy untuk operasi matematika dan numerik yang cepat, pandas untuk menganalisis dan maanipulasi data, cv2 untuk pengolahan citra komputer, cv2_imshow untuk menaampilkan gambar secara langsung, io untuk membaca dan menulis format gambar, transform untuk transformasi citra, image untuk membuka, menyimpan, dan melakukan berbagai operasi pada gambar, plt untuk visualisasi data**
#
# **tidak, ada yang tidak harus digunakan seperti numpy, pandas, plt**
#
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# jawab ->
# **kegunaan kode tsb untuk merubah ukuran gambar dari aslinya menjadi lebih kecil dan memfix kan gambar, jika tidak dilakukan maka gambar akan menampilkan gambar seperti aslinya dengan paksaan yang hasilnya akan terjadi gambar kedip2**
#
# 4. Perhatikan potongan kode progam berikut :Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# jawab ->
# **digunakan untuk mengubah semua piksel pada baris tengah gambar'image_3' menjadi warna putih**
#
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# jawab ->
# **Gambar dengan resolusi tinggi memiliki lebih banyak piksel per unit area, sehingga menjadikan gambar menjadi lebih jelas. Gambar dengan resolusi rendah memiliki lebih sedikit piksel per unit area, sehingga gambar tampak kabur**

# %% [markdown]
# # SOAL

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

for y in range(min(tinggi, lebar)):
  image_4[y, y] = [255, 255, 255]
  image_4[1 - y, y] = [255, 255, 255]

final_frame1 = cv.hconcat((image_2, image_3))
final_frame2 = cv.hconcat((image_2, image_4))

cv2_imshow(final_frame1)
print('\n')
cv2_imshow(final_frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range ((tinggi - 100)//2, (tinggi - 100)//2 + 100 ):
  image_3[int((tinggi)/2), x] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))

cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range ((tinggi - 100)//2, (tinggi - 100)//2 + 100 ):
  for y in range((lebar - 100) //2, (lebar - 100) // 2 + 100):
    image_3[x+7,y-50] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))

cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # KELOMPOK

# %%
image_path = 'KTP.jpeg'

# Baca gambar menggunakan OpenCV
image = cv.imread(image_path)

# Konversi format warna dari BGR (OpenCV) ke RGB (Matplotlib)
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image_rgb)
# plt.axis('off')  # Matplotlib tidak menampilkan sumbu
plt.show()

# %% [markdown]
# 2.**Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv**
#
# ---
#
# jawab -> **untuk mengonversi format warna dari BGR ke RGB. Ini diperlukan karena perbedaan dalam urutan komponen warna antara BGR dan RGB. OpenCV mengatur kanal biru (B) sebagai komponen pertama, diikuti oleh komponen hijau (G) dan kemudian merah (R), sedangkan format RGB mengikuti urutan R, G, B. sehingga bisa ditampilkan dengan benar oleh matplotlib**

# %%
import cv2
import matplotlib.pyplot as plt

# Ganti dengan path gambar Anda
image_path = 'KTP.jpeg'

# Baca gambar menggunakan OpenCV
image = cv2.imread(image_path)

# Membuat salinan gambar untuk dimodifikasi
image_copy = image.copy()

# Menentukan koordinat dan ukuran kotak
x_box = 195
y_box = 375
width_box = 200
height_box = 20

# Membuat gambar baru dengan kotak berwarna kuning
image_with_box = image_rgb
for y in range(y_box, y_box + height_box):
    for x in range(x_box, x_box + width_box):
        image_copy[y, x] = [0, 255, 0]

# Koordinat sudut kotak
x_start, y_start = 200, 90
x_end, y_end = 400, 330

box_color = [0, 0, 255]

# Loop untuk menggambar kotak pada gambar
for y in range(y_start, y_end):
    for x in range(x_start, x_end):
        image_copy[y, x + 370] = box_color

# Konversi format warna dari BGR (OpenCV) ke RGB (Matplotlib)
image_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

# Tampilkan gambar dengan kotak menggunakan
plt.imshow(image_rgb)
plt.show()
